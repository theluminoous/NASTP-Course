# %% [markdown]
# ## What is Pandas?
# Pandas is a Python library used for working with data sets.
# It has functions for analyzing, cleaning, exploring, and manipulating data.
#
# ## Why Use Pandas?
# Pandas allows us to analyze big data and make conclusions based on statistical theories.
# Pandas can clean messy data sets, and make them readable and relevant.
# Relevant data is very important in data science.

# %% [markdown]
# ### Outline
# ---
# 1 Read CSV Files
# 2 Selecting Columns
# 3 Selecting rows
# 4 loc
# 5 iloc
# 6 WHR Exercise
# 7 Solution
# 8 Series

# %%
import pandas as pd

# %%
# 1. Same Directory: reading a CSV file from other Directory
dataset = pd.read_csv('tmdb_5000_movies.csv')
dataset
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
# 2. Other Directory: reading a CSV file from other Directory
dataset_2 = pd.read_csv(r'C:\Users\hasee\OneDrive\Desktop\AI Course\Artificial Intelligence Class/master.csv')
dataset_2

# or 

dataset_2 = pd.read_csv('C://Users//hasee//OneDrive//Desktop//AI Course//Artificial Intelligence Class//master.csv')
dataset_2

# %%
# 2. Other Directory: reading a CSV file from other Directory
dataset_2 = pd.read_csv(r'C:\Users\hasee\OneDrive\Desktop\AI Course\Artificial Intelligence Class/master.csv')
dataset_2

# or 

dataset_2 = pd.read_csv('C://Users//hasee//OneDrive//Desktop//AI Course//Artificial Intelligence Class//master.csv')
dataset_2
# Out:
#           country  year  gender          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# ...           ...   ...     ...          ...          ...         ...
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# ...

# %%
# 3. Online File: reading a CSV file from a URL
df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
type(dataset)     #output--> pandas.core.frame.DataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
#To check the shape of dataset in the form of coloumns and rows
dataset.shape
# Out:
# (4803, 20)

# %%
# to check all coloumns of dataset
dataset.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
# to check index of dataset
dataset.index
# Out:
# RangeIndex(start=0, stop=4803, step=1)

# %%
# to print top 5 rows of dataset we will use head
dataset.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
# to print last 5 rows of dataset we will use tail
dataset.tail()
# Out:
#       budget                                             genres  \
# 4798  220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799    9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800       0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801       0                                                 []
# 4802       0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 4798                                                NaN    9367
# 4799                                                NaN   72766
# 4800  http://www.hallmarkchannel.com/signedsealeddel...  231617
# 4801                        http://shanghaicalling.com/  126186
# 4802                                                NaN   25975
#
#                                                keywords original_language  \
# 4798  [{"id": 5616, "name": "united states\u2013mexi...                es
# ...

# %%
# to print top n rows of dataset we will use head(n)
dataset.head(10)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5  258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6  260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7  280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8  250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9  250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             homepage      id  \
# 0                        http://www.avatarmovie.com/   19995
# 1       http://disney.go.com/disneypictures/pirates/     285
# 2        http://www.sonypictures.com/movies/spectre/  206647
# ...

# %%
# to check all info of dataset
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
dataset.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# ...

# %% [markdown]
# # Selecting Coloumns

# %%
# to print specific coloumn
dataset['budget']                #print in series format
# Out:
# 0       237000000
# 1       300000000
# 2       245000000
# 3       250000000
# 4       260000000
#           ...
# 4798       220000
# 4799         9000
# 4800            0
# 4801            0
# 4802            0
# Name: budget, Length: 4803, dtype: int64

# %%
dataset[['revenue']]              #print in dataframe format
# Out:
#          revenue
# 0     2787965087
# 1      961000000
# 2      880674609
# 3     1084939099
# 4      284139100
# ...          ...
# 4798     2040920
# 4799           0
# 4800           0
# 4801           0
# 4802           0
#
# [4803 rows x 1 columns]

# %%
# to print more than one specific coloumns
dataset[['original_title','original_language','budget','revenue']]    #print more than one coloumn in dataframe into your given order
# Out:
#                                 original_title original_language     budget  \
# 0                                       Avatar                en  237000000
# 1     Pirates of the Caribbean: At World's End                en  300000000
# 2                                      Spectre                en  245000000
# 3                        The Dark Knight Rises                en  250000000
# 4                                  John Carter                en  260000000
# ...                                        ...               ...        ...
# 4798                               El Mariachi                es     220000
# 4799                                 Newlyweds                en       9000
# 4800                 Signed, Sealed, Delivered                en          0
# 4801                          Shanghai Calling                en          0
# 4802                         My Date with Drew                en          0
#
#          revenue
# 0     2787965087
# 1      961000000
# ...

# %%
dataset[['original_title','original_language','budget','revenue']].head(10)
# Out:
#                              original_title original_language     budget  \
# 0                                    Avatar                en  237000000
# 1  Pirates of the Caribbean: At World's End                en  300000000
# 2                                   Spectre                en  245000000
# 3                     The Dark Knight Rises                en  250000000
# 4                               John Carter                en  260000000
# 5                              Spider-Man 3                en  258000000
# 6                                   Tangled                en  260000000
# 7                   Avengers: Age of Ultron                en  280000000
# 8    Harry Potter and the Half-Blood Prince                en  250000000
# 9        Batman v Superman: Dawn of Justice                en  250000000
#
#       revenue
# 0  2787965087
# 1   961000000
# 2   880674609
# 3  1084939099
# 4   284139100
# 5   890871626
# 6   591794936
# 7  1405403694
# 8   933959197
# ...

# %% [markdown]
# # Selecting rows

# %%
# Columns were accessed by coloumn name but rows will be accessed by row number
dataset[0:3]
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
# ...

# %%
# lets store rows data in a variable and then get specific coloumns from given data
data = dataset[0:5]
data[['original_title','release_date']]
# Out:
#                              original_title release_date
# 0                                    Avatar   2009-12-10
# 1  Pirates of the Caribbean: At World's End   2007-05-19
# 2                                   Spectre   2015-10-26
# 3                     The Dark Knight Rises   2012-07-16
# 4                               John Carter   2012-03-07

# %% [markdown]
# # loc

# %%
dataset.loc[0]   #in loc & iloc single number can be given
# Out:
# budget                                                          237000000
# genres                  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# homepage                                      http://www.avatarmovie.com/
# id                                                                  19995
# keywords                [{"id": 1463, "name": "culture clash"}, {"id":...
# original_language                                                      en
# original_title                                                     Avatar
# overview                In the 22nd century, a paraplegic Marine is di...
# popularity                                                     150.437577
# production_companies    [{"name": "Ingenious Film Partners", "id": 289...
# production_countries    [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                   2009-12-10
# revenue                                                        2787965087
# ...

# %%
dataset.loc[0:3] # in just loc, last number of slicing also counted
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
#
# ...

# %%
# we can change first coloumn of number index with desired coloumn
dataset_2 = pd.read_csv('tmdb_5000_movies.csv', index_col = 'original_title')

# %%
dataset_2
# Out:
#                                              budget  \
# original_title
# Avatar                                    237000000
# Pirates of the Caribbean: At World's End  300000000
# Spectre                                   245000000
# The Dark Knight Rises                     250000000
# John Carter                               260000000
# ...                                             ...
# El Mariachi                                  220000
# Newlyweds                                      9000
# Signed, Sealed, Delivered                         0
# Shanghai Calling                                  0
# My Date with Drew                                 0
#
#                                                                                      genres  \
# original_title
# Avatar                                    [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# Pirates of the Caribbean: At World's End  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# ...

# %%
# due to this index coloumn, we can search movie by name
dataset_2.loc[['Avatar','Spectre']] # more than one rows
# Out:
#                    budget                                             genres  \
# original_title
# Avatar          237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# Spectre         245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                                    homepage      id  \
# original_title
# Avatar                          http://www.avatarmovie.com/   19995
# Spectre         http://www.sonypictures.com/movies/spectre/  206647
#
#                                                          keywords  \
# original_title
# Avatar          [{"id": 1463, "name": "culture clash"}, {"id":...
# Spectre         [{"id": 470, "name": "spy"}, {"id": 818, "name...
#
#                original_language  \
# original_title
# Avatar                        en
# Spectre                       en
#
#                                                          overview  popularity  \
# original_title
# ...

# %%
# to select specific coloumns from specific rows
dataset_2.loc[['Avatar','Spectre'],['original_language','budget']]
# Out:
#                original_language     budget
# original_title
# Avatar                        en  237000000
# Spectre                       en  245000000

# %% [markdown]
# # iloc

# %%
dataset
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
dataset.iloc[0]         # single row
# Out:
# budget                                                          237000000
# genres                  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# homepage                                      http://www.avatarmovie.com/
# id                                                                  19995
# keywords                [{"id": 1463, "name": "culture clash"}, {"id":...
# original_language                                                      en
# original_title                                                     Avatar
# overview                In the 22nd century, a paraplegic Marine is di...
# popularity                                                     150.437577
# production_companies    [{"name": "Ingenious Film Partners", "id": 289...
# production_countries    [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                   2009-12-10
# revenue                                                        2787965087
# ...

# %%
dataset.iloc[0:5]       # slice of row excluding last number
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
dataset.iloc[[0,3,6,7]] # list of rows
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 6  260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7  280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             homepage     id  \
# 0                        http://www.avatarmovie.com/  19995
# 3                 http://www.thedarkknightrises.com/  49026
# 6       http://disney.go.com/disneypictures/tangled/  38757
# 7  http://marvel.com/movies/movie/193/avengers_ag...  99861
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 6  [{"id": 1562, "name": "hostage"}, {"id": 2343,...                en
# ...

# %%
dataset.iloc[2:6,2:4]   # rows , coloumns
# Out:
#                                           homepage      id
# 2      http://www.sonypictures.com/movies/spectre/  206647
# 3               http://www.thedarkknightrises.com/   49026
# 4             http://movies.disney.com/john-carter   49529
# 5  http://www.sonypictures.com/movies/spider-man3/     559

# %%
dataset.iloc[[2,5,9],[3,9]]
# Out:
#        id                               production_companies
# 2  206647  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 5     559  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 9  209112  [{"name": "DC Comics", "id": 429}, {"name": "A...

# %%
dataset.iloc[[2,5,9],0:6]
# Out:
#       budget                                             genres  \
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5  258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 9  250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                           homepage      id  \
# 2      http://www.sonypictures.com/movies/spectre/  206647
# 5  http://www.sonypictures.com/movies/spider-man3/     559
# 9     http://www.batmanvsupermandawnofjustice.com/  209112
#
#                                             keywords original_language
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 5  [{"id": 851, "name": "dual identity"}, {"id": ...                en
# 9  [{"id": 849, "name": "dc comics"}, {"id": 7002...                en

# %%
dataset.iloc[[2,5,9],0]
# Out:
# 2    245000000
# 5    258000000
# 9    250000000
# Name: budget, dtype: int64

# %% [markdown]
# ### Difference between loc and iloc
# ---
# 1. loc is label-based, which means that you have to specify rows and columns based on their row and column labels.
# 2. iloc is integer position-based, so you have to specify rows and columns by their integer position values (0-based integer position)

# %% [markdown]
# ### Your Task
# ---
# 1. Find top five happiest countries
# 2. Find least five happiest countries
# 3. Print all the column names
# 4. Print row index and meta information
# 5. use iloc and find the countries with happiness index from 5th to 10th
# 6. change index_col and find the happiness rank of pakistan, china, russia

# %%
dataset_whr = pd.read_csv('2019.csv')
dataset_whr
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
# 1. Find top five happiest countries
# dataset_whr.iloc[0:5]
# or
dataset_whr.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
# 2. Find least five happiest countries
# dataset_whr.tail()

# or

dataset_whr.iloc[-1:-6:-1]
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 155           156               South Sudan  2.853           0.306
# 154           155  Central African Republic  3.083           0.026
# 153           154               Afghanistan  3.203           0.350
# 152           153                  Tanzania  3.231           0.476
# 151           152                    Rwanda  3.334           0.359
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 155           0.575                    0.295                         0.010
# 154           0.000                    0.105                         0.225
# 153           0.517                    0.361                         0.000
# 152           0.885                    0.499                         0.417
# 151           0.711                    0.614                         0.555
#
#      Generosity  Perceptions of corruption
# 155       0.202                      0.091
# ...

# %%
# 3. Print all the column names
dataset_whr.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
# 4. Print row index and meta information
dataset_whr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
# 5. use iloc and find the countries with happiness index from 5th to 10th
dataset_whr.iloc[4:10]
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 4             5       Netherlands  7.488           1.396           1.522
# 5             6       Switzerland  7.480           1.452           1.526
# 6             7            Sweden  7.343           1.387           1.487
# 7             8       New Zealand  7.307           1.303           1.557
# 8             9            Canada  7.278           1.365           1.505
# 9            10           Austria  7.246           1.376           1.475
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 4                    0.999                         0.557       0.322
# 5                    1.052                         0.572       0.263
# 6                    1.009                         0.574       0.267
# 7                    1.026                         0.585       0.330
# 8                    1.039                         0.584       0.285
# ...

# %%
# 6. change index_col and find the happiness rank of pakistan, china, Russia
dataset_whrci = pd.read_csv('2019.csv', index_col = 'Country or region')
dataset_whrci.loc[['Pakistan','China','Russia','India']]
# Out:
#                    Overall rank  Score  GDP per capita  Social support  \
# Country or region
# Pakistan                     67  5.653           0.677           0.886
# China                        93  5.191           1.029           1.125
# Russia                       68  5.648           1.183           1.452
# India                       140  4.015           0.755           0.765
#
#                    Healthy life expectancy  Freedom to make life choices  \
# Country or region
# Pakistan                             0.535                         0.313
# China                                0.893                         0.521
# Russia                               0.726                         0.334
# India                                0.588                         0.498
#
#                    Generosity  Perceptions of corruption
# Country or region
# Pakistan                0.220                      0.098
# China                   0.058                      0.100
# ...

# %% [markdown]
# ## Series in Pandas

# %%
dataset_md = pd.read_csv('tmdb_5000_movies.csv')
dataset_md.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
ser = dataset_md['budget']
# ser

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
# some functions of 'Series' and 'DataFrame' are same excluding .info()
ser.head()
ser.head(10)
ser.dtype           #to check datatype, not work for dataframe
# dataset_md.info() #this function only works for dataframe
# ser.info()        #Cann't use for series
ser.shape           #rows and coloumn's detail
ser.size            #total elements
ser.describe()      #statistical info
ser.index           #rows detail

# %% [markdown]
# ## Functions for Numerical Series

# %%
ser = dataset_md['runtime']
ser.head()
# Out:
# 0    162.0
# 1    169.0
# 2    148.0
# 3    165.0
# 4    132.0
# Name: runtime, dtype: float64

# %%
ser.sum() #sum of all values
# Out:
# 513111.0

# %%
ser.size #total values (including nan) in selected coloumn
# Out:
# 4803

# %%
ser.count() #total values (excluding nan) in selected coloumn
# Out:
# 4801

# %%
ser.size - ser.count() #count missing or undefined values
# Out:
# 2

# %%
ser.mean() #average time of movies
# Out:
# 106.87585919600083

# %%
ser.std() # amount of dispersion of a set of values
# Out:
# 22.611934588844207

# %%
ser.median() #middle value in sorted data
# Out:
# 103.0

# %%
ser.mode() #value comes most often
# Out:
# 0    90.0
# Name: runtime, dtype: float64

# %%
ser.min() #it shows that, here some movie also has 0 run time
# Out:
# 0.0

# %%
ser.max() #maximum run time
# Out:
# 338.0

# %%
ser.unique() #unique runtimes of movies including nan
# Out:
# array([162., 169., 148., 165., 132., 139., 100., 141., 153., 151., 154.,
#        106., 149., 143., 150., 136., 144., 140., 161., 113., 187., 194.,
#        147., 131., 124., 127., 130., 108., 104., 142., 125., 114., 103.,
#        115., 137., 116., 122.,  93.,  98.,  91., 158.,  96., 109., 152.,
#         94., 126., 112., 123., 135., 118.,  97., 119., 102., 120., 121.,
#        166.,  99., 183., 175., 138., 157.,  92., 101., 111.,  89., 105.,
#        107., 129.,  88.,  85., 163., 133.,  95.,  90., 110., 128., 156.,
#        117., 146.,  82.,  78., 134., 170.,  76., 178.,  84., 155., 145.,
#        180., 172., 167., 201., 179.,  83.,  87.,  80.,  74.,  81., 177.,
#         86., 164., 159., 191., 189., 214.,   0.,  75., 192., 160., 219.,
#        248., 188., 202., 173., 195.,  77.,  79.,  63., 229., 193., 254.,
#         72.,  68., 199., 181., 242., 338.,  73., 216., 276.,  nan, 200.,
#         69., 197., 184., 176., 185., 171., 174.,  46.,  53.,  42., 240.,
# ...

# %%
ser.unique().size
# or 
len(ser.unique())
# Out:
# 157

# %%
ser.nunique() #non count nan values
# Out:
# 156

# %%
ser.value_counts() #counts repeted values in descending order
# Out:
# runtime
# 90.0     163
# 100.0    149
# 98.0     140
# 97.0     133
# 95.0     123
#         ...
# 338.0      1
# 216.0      1
# 166.0      1
# 194.0      1
# 60.0       1
# Name: count, Length: 156, dtype: int64

# %%
ser.value_counts(ascending = True)
# Out:
# runtime
# 60.0       1
# 194.0      1
# 184.0      1
# 276.0      1
# 216.0      1
#         ...
# 95.0     123
# 97.0     133
# 98.0     140
# 100.0    149
# 90.0     163
# Name: count, Length: 156, dtype: int64

# %% [markdown]
# ## How to create Pandas Series

# %%
# First way, by selecting one coloumn of dataset
ser = dataset_md['runtime']
ser.head()
# Out:
# 0    162.0
# 1    169.0
# 2    148.0
# 3    165.0
# 4    132.0
# Name: runtime, dtype: float64

# %%
# Creating series from dictionary
dic = {
    "Avatar"                                   : 162.0,
    "Pirates of the Caribbean: At World's End" : 169.0,
    "Spectre"                                  : 148.0,
    "The Dark Knight Rises"                    : 165.0,
    "John Carter"                              : 132.0,
    "Spider-Man 3"                             : 139.0,
    "Tangled"                                  : 100.0,
    "Avengers: Age of Ultron"                  : 141.0,
    "Harry Potter and the Half-Blood Prince"   : 153.0,
    "Batman v Superman: Dawn of Justice"       : 151.0
}

# %%
pd.Series(dic)
# Out:
# Avatar                                      162.0
# Pirates of the Caribbean: At World's End    169.0
# Spectre                                     148.0
# The Dark Knight Rises                       165.0
# John Carter                                 132.0
# Spider-Man 3                                139.0
# Tangled                                     100.0
# Avengers: Age of Ultron                     141.0
# Harry Potter and the Half-Blood Prince      153.0
# Batman v Superman: Dawn of Justice          151.0
# dtype: float64

# %%
dic = {
    'Honda City'     : 31.7,
    'Toyota Corolla' :38.9,
    'Toyota Yaris'   :29.0,
    'Suzuki Wagon R' : 17.6
}
car_prices = pd.Series(dic)

# %%
# sorted from smallest to highest
car_prices.nsmallest()
# Out:
# Suzuki Wagon R    17.6
# Toyota Yaris      29.0
# Honda City        31.7
# Toyota Corolla    38.9
# dtype: float64

# %%
# one row with smallest value
car_prices.nsmallest(n=1)
# Out:
# Suzuki Wagon R    17.6
# dtype: float64

# %%
# name of smallest value
car_prices.nsmallest().index[0]
# Out:
# 'Suzuki Wagon R'

# %%
car_prices.nsmallest().index[3]
# Out:
# 'Toyota Corolla'

# %%
# gives minimum index
car_prices.idxmin()
# Out:
# 'Suzuki Wagon R'

# %%
# gives maximum index
car_prices.idxmax()
# Out:
# 'Toyota Corolla'

# %% [markdown]
# ## How to filter data in pandas

# %%
dataset_sro = pd.read_csv('master.csv')
dataset_sro
# Out:
#           country  year  gender          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# ...           ...   ...     ...          ...          ...         ...
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# ...

# %%
# to check a specific coloumn
dataset_sro.country
# Out:
# 0           Albania
# 1           Albania
# 2           Albania
# 3           Albania
# 4           Albania
#             ...
# 27815    Uzbekistan
# 27816    Uzbekistan
# 27817    Uzbekistan
# 27818    Uzbekistan
# 27819    Uzbekistan
# Name: country, Length: 27820, dtype: object

# %%
dataset_sro.country.unique()
# Out:
# array(['Albania', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Barbados', 'Belarus', 'Belgium', 'Belize',
#        'Bosnia and Herzegovina', 'Brazil', 'Bulgaria', 'Cabo Verde',
#        'Canada', 'Chile', 'Colombia', 'Costa Rica', 'Croatia', 'Cuba',
#        'Cyprus', 'Czech Republic', 'Denmark', 'Dominica', 'Ecuador',
#        'El Salvador', 'Estonia', 'Fiji', 'Finland', 'France', 'Georgia',
#        'Germany', 'Greece', 'Grenada', 'Guatemala', 'Guyana', 'Hungary',
#        'Iceland', 'Ireland', 'Israel', 'Italy', 'Jamaica', 'Japan',
#        'Kazakhstan', 'Kiribati', 'Kuwait', 'Kyrgyzstan', 'Latvia',
#        'Lithuania', 'Luxembourg', 'Macau', 'Maldives', 'Malta',
#        'Mauritius', 'Mexico', 'Mongolia', 'Montenegro', 'Netherlands',
#        'New Zealand', 'Nicaragua', 'Norway', 'Oman', 'Panama', 'Paraguay',
#        'Philippines', 'Poland', 'Portugal', 'Puerto Rico', 'Qatar',
# ...

# %%
# to Check a specific country
# output in boolean form
dataset_sro.country == 'Sri Lanka'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 27815    False
# 27816    False
# 27817    False
# 27818    False
# 27819    False
# Name: country, Length: 27820, dtype: bool

# %%
dataset_sro[dataset_sro.country == 'Sri Lanka']
# Out:
#          country  year  gender          age  suicides_no  population  \
# 23900  Sri Lanka  1985    male    75+ years          144      115000
# 23901  Sri Lanka  1985    male  15-24 years         1432     1673000
# 23902  Sri Lanka  1985    male  25-34 years         1024     1288000
# 23903  Sri Lanka  1985    male  55-74 years          443      680000
# 23904  Sri Lanka  1985  female  15-24 years          943     1652000
# ...          ...   ...     ...          ...          ...         ...
# 24027  Sri Lanka  2006  female  25-34 years          194     1594072
# 24028  Sri Lanka  2006  female  55-74 years          111     1344897
# 24029  Sri Lanka  2006  female  35-54 years          198     2603293
# 24030  Sri Lanka  2006    male   5-14 years           15     1650300
# 24031  Sri Lanka  2006  female   5-14 years           11     1606015
#
#        suicides/100k pop   country-year  HDI for year  gdp_for_year ($)   \
# ...

# %%
# further filter to specific year
dataset_sro[(dataset_sro.country == 'Sri Lanka') & (dataset_sro.year == 1985)]
# Out:
#          country  year  gender          age  suicides_no  population  \
# 23900  Sri Lanka  1985    male    75+ years          144      115000
# 23901  Sri Lanka  1985    male  15-24 years         1432     1673000
# 23902  Sri Lanka  1985    male  25-34 years         1024     1288000
# 23903  Sri Lanka  1985    male  55-74 years          443      680000
# 23904  Sri Lanka  1985  female  15-24 years          943     1652000
# 23905  Sri Lanka  1985    male  35-54 years          824     1469000
# 23906  Sri Lanka  1985  female  25-34 years          426     1268000
# 23907  Sri Lanka  1985  female    75+ years           23      106000
# 23908  Sri Lanka  1985  female  35-54 years          203     1402000
# 23909  Sri Lanka  1985  female  55-74 years           80      600000
# 23910  Sri Lanka  1985    male   5-14 years           71     1836000
# 23911  Sri Lanka  1985  female   5-14 years           55     1768000
#
# ...

# %%
cond1 = dataset_sro.country == 'Sri Lanka'
cond2 = dataset_sro.year == 1985
dataset_sro[cond1 & cond2]
# Out:
#          country  year  gender          age  suicides_no  population  \
# 23900  Sri Lanka  1985    male    75+ years          144      115000
# 23901  Sri Lanka  1985    male  15-24 years         1432     1673000
# 23902  Sri Lanka  1985    male  25-34 years         1024     1288000
# 23903  Sri Lanka  1985    male  55-74 years          443      680000
# 23904  Sri Lanka  1985  female  15-24 years          943     1652000
# 23905  Sri Lanka  1985    male  35-54 years          824     1469000
# 23906  Sri Lanka  1985  female  25-34 years          426     1268000
# 23907  Sri Lanka  1985  female    75+ years           23      106000
# 23908  Sri Lanka  1985  female  35-54 years          203     1402000
# 23909  Sri Lanka  1985  female  55-74 years           80      600000
# 23910  Sri Lanka  1985    male   5-14 years           71     1836000
# 23911  Sri Lanka  1985  female   5-14 years           55     1768000
#
# ...

# %%
cond1 = dataset_sro.country == 'Sri Lanka'
cond2 = dataset_sro.year == 1985
cond3 = dataset_sro.year == 2006
dataset_sro[cond1 & (cond2 | cond3)]
# Out:
#          country  year  gender          age  suicides_no  population  \
# 23900  Sri Lanka  1985    male    75+ years          144      115000
# 23901  Sri Lanka  1985    male  15-24 years         1432     1673000
# 23902  Sri Lanka  1985    male  25-34 years         1024     1288000
# 23903  Sri Lanka  1985    male  55-74 years          443      680000
# 23904  Sri Lanka  1985  female  15-24 years          943     1652000
# 23905  Sri Lanka  1985    male  35-54 years          824     1469000
# 23906  Sri Lanka  1985  female  25-34 years          426     1268000
# 23907  Sri Lanka  1985  female    75+ years           23      106000
# 23908  Sri Lanka  1985  female  35-54 years          203     1402000
# 23909  Sri Lanka  1985  female  55-74 years           80      600000
# 23910  Sri Lanka  1985    male   5-14 years           71     1836000
# 23911  Sri Lanka  1985  female   5-14 years           55     1768000
# 24020  Sri Lanka  2006    male    75+ years          211      224927
# ...

# %%
# to filter specific coloumns also
dataset_sro.loc[cond1 & (cond2 | cond3),['gender']]
# Out:
#        gender
# 23900    male
# 23901    male
# 23902    male
# 23903    male
# 23904  female
# 23905    male
# 23906  female
# 23907  female
# 23908  female
# 23909  female
# 23910    male
# 23911  female
# 24020    male
# 24021    male
# 24022    male
# 24023    male
# 24024    male
# 24025  female
# 24026  female
# 24027  female
# 24028  female
# 24029  female
# 24030    male
# 24031  female

# %%
cond1 = dataset_sro.country == 'Sri Lanka'
cond2 = dataset_sro.year == 1985
cond3 = dataset_sro.year == 2006
cond4 = dataset_sro.gender == 'male'
cd = dataset_sro[cond1 & (cond2 | cond3) & cond4]
cd
# Out:
#          country  year gender          age  suicides_no  population  \
# 23900  Sri Lanka  1985   male    75+ years          144      115000
# 23901  Sri Lanka  1985   male  15-24 years         1432     1673000
# 23902  Sri Lanka  1985   male  25-34 years         1024     1288000
# 23903  Sri Lanka  1985   male  55-74 years          443      680000
# 23905  Sri Lanka  1985   male  35-54 years          824     1469000
# 23910  Sri Lanka  1985   male   5-14 years           71     1836000
# 24020  Sri Lanka  2006   male    75+ years          211      224927
# 24021  Sri Lanka  2006   male  55-74 years          649     1187973
# 24022  Sri Lanka  2006   male  35-54 years         1246     2465505
# 24023  Sri Lanka  2006   male  25-34 years          573     1541529
# 24024  Sri Lanka  2006   male  15-24 years          423     1697398
# 24030  Sri Lanka  2006   male   5-14 years           15     1650300
#
#        suicides/100k pop   country-year  HDI for year  gdp_for_year ($)   \
# ...

# %%
# to sum the values of a coloumn
cd.sum().suicides_no
# Out:
# 7055

# %%
cond1 = dataset_sro.country == 'Sri Lanka'
cond2 = dataset_sro.year >= 2000 #years greater or equal to 2000
cd = dataset_sro[cond1 & cond2]
cd
# Out:
#          country  year  gender          age  suicides_no  population  \
# 23972  Sri Lanka  2000    male    75+ years          200      196877
# 23973  Sri Lanka  2000    male  55-74 years          729      999107
# 23974  Sri Lanka  2000    male  35-54 years         1521     2331906
# 23975  Sri Lanka  2000    male  25-34 years          873     1464384
# 23976  Sri Lanka  2000    male  15-24 years          615     1815183
# 23977  Sri Lanka  2000  female  15-24 years          504     1776940
# 23978  Sri Lanka  2000  female  25-34 years          288     1495529
# 23979  Sri Lanka  2000  female    75+ years           40      210936
# 23980  Sri Lanka  2000  female  35-54 years          309     2394085
# 23981  Sri Lanka  2000  female  55-74 years          125     1072256
# 23982  Sri Lanka  2000  female   5-14 years           27     1659830
# 23983  Sri Lanka  2000    male   5-14 years           21     1723309
# 23984  Sri Lanka  2001    male    75+ years          162      204801
# ...

# %%
cond1 = dataset_sro.country == 'Sri Lanka'
# cond2 = dataset_sro.year >= 2000 #years greater or equal to 2000
cond3 = dataset_sro.year.between(1990,2000) #data between these two years
cd = dataset_sro[cond1 & cond3]
cd
# Out:
#          country  year  gender          age  suicides_no  population  \
# 23924  Sri Lanka  1996    male    75+ years          146      191662
# 23925  Sri Lanka  1996    male  55-74 years          648      919081
# 23926  Sri Lanka  1996    male  25-34 years          918     1524411
# 23927  Sri Lanka  1996    male  35-54 years         1211     2095820
# 23928  Sri Lanka  1996    male  15-24 years          768     1772399
# 23929  Sri Lanka  1996  female  15-24 years          500     1726757
# 23930  Sri Lanka  1996  female  25-34 years          284     1516469
# 23931  Sri Lanka  1996  female    75+ years           30      196180
# 23932  Sri Lanka  1996  female  35-54 years          228     2135855
# 23933  Sri Lanka  1996  female  55-74 years          102      966021
# 23934  Sri Lanka  1996    male   5-14 years           37     1840930
# 23935  Sri Lanka  1996  female   5-14 years           26     1768842
# 23936  Sri Lanka  1997    male    75+ years          181      195537
# ...

# %%
cond1 = dataset_sro.country == 'Sri Lanka'
# cond2 = dataset_sro.year >= 2000 #years greater or equal to 2000
# cond3 = dataset_sro.year.between(1990,2000)
cond3 = dataset_sro.year.isin([1990,2000]) #data of these two years
cd = dataset_sro[cond1 & cond4]
cd
# Out:
#          country  year gender          age  suicides_no  population  \
# 23900  Sri Lanka  1985   male    75+ years          144      115000
# 23901  Sri Lanka  1985   male  15-24 years         1432     1673000
# 23902  Sri Lanka  1985   male  25-34 years         1024     1288000
# 23903  Sri Lanka  1985   male  55-74 years          443      680000
# 23905  Sri Lanka  1985   male  35-54 years          824     1469000
# ...          ...   ...    ...          ...          ...         ...
# 24021  Sri Lanka  2006   male  55-74 years          649     1187973
# 24022  Sri Lanka  2006   male  35-54 years         1246     2465505
# 24023  Sri Lanka  2006   male  25-34 years          573     1541529
# 24024  Sri Lanka  2006   male  15-24 years          423     1697398
# 24030  Sri Lanka  2006   male   5-14 years           15     1650300
#
#        suicides/100k pop   country-year  HDI for year  gdp_for_year ($)   \
# 23900             125.22  Sri Lanka1985         0.597      5,978,460,972
# ...

# %%
# to oppose the condition
cond2 = dataset_sro.year >= 2000
dataset_sro.loc[~cond2]
# Out:
#           country  year  gender          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# ...           ...   ...     ...          ...          ...         ...
# 27671  Uzbekistan  1999  female  25-34 years           98     1842587
# 27672  Uzbekistan  1999  female  55-74 years           39      923365
# 27673  Uzbekistan  1999  female  35-54 years           89     2257145
# 27674  Uzbekistan  1999    male   5-14 years           59     3260451
# 27675  Uzbekistan  1999  female   5-14 years           18     3155241
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# ...
